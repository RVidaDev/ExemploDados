# %% [markdown]
# ## 1. Preparar o ambiente
# instalar  e importar

# %%
##!pip install pandas matplotlib seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.__version__
# Out:
# '1.5.3'

# %% [markdown]
# ## 2. carregar os dados

# %%
df = pd.read_csv("./survey/survey.csv")

# %%
df.sample()

# %%
df.shape

# %%
df.tail()

# %% [markdown]
# ## 3. limpeza de dados
# 1. tratar dados faltantes (remover/preencher)
# 2. remover dados duplicados
# 3. remover colunas pouco informativas

# %%
df_clean = df.dropna()

# %%
df_double_clean = df_clean.drop_duplicates()

# %%
df_double_clean.drop("user_id", axis=1, inplace=True)

# %% [markdown]
# ## 4. Estatísticas *descritivas*

# %%
df_double_clean.describe()
# Out:
#              age         q1         q2         q3         q4         q5  \
# count  60.000000  60.000000  60.000000  60.000000  60.000000  60.000000
# mean   25.016667   8.000000   7.816667   7.933333   7.400000   7.666667
# std    11.293453   2.292212   1.908870   2.246403   2.035282   1.762766
# min     2.000000   1.000000   1.000000   1.000000   2.000000   2.000000
# 25%    19.000000   7.000000   7.000000   7.000000   6.000000   7.000000
# 50%    20.000000   9.000000   8.000000   9.000000   8.000000   8.000000
# 75%    27.500000  10.000000   9.000000  10.000000   9.000000   9.000000
# max    55.000000  10.000000  10.000000  10.000000  10.000000  10.000000
#
#               q6         q7         q8         q9  ...        q17        q18  \
# count  60.000000  60.000000  60.000000  60.000000  ...  60.000000  60.000000
# mean    7.766667   7.783333   7.783333   7.433333  ...   8.350000   7.700000
# std     2.036669   2.017648   1.905315   2.142125  ...   1.929477   1.951097
# ...

# %%
plt.figure()

sns.kdeplot(df_double_clean, x="age")

plt.show()

# %%
plt.figure(figsize=(16,15))

sns.heatmap(
    df_double_clean.corr(),
    annot=True,

)

plt.show()
# Out:
# C:\Users\logonrmlocal\AppData\Local\Temp\ipykernel_11884\1196642613.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_double_clean.corr(),
